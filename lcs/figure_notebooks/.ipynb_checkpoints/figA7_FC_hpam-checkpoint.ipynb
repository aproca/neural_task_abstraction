# %%
import sys
sys.path.append('../..')
from lcs import SRC_ROOT
import json
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
import copy
from lcs.configs import Config
from run_script import get_data
import matplotlib.cm as cm
from matplotlib.colors import Normalize
from lcs import TEXTWIDTH, PAGEHEIGHT
from lcs.plotting_utils import *

# %%
shared_cfg = Config(input_size=20,
       output_size=10,
       num_seeds=10, #1,
       num_contexts=2,
       num_paths=2,
       batch_size=200,
       initialization_scale=0.01,
       regularization_strength=0.25, 
       num_layers=2,
       hidden_size=10,
       context_model=False,
       name='',
       regularization_type=[('nonnegative', 1),
                            ('gating_manifold_L2', 10.0)],
       shared_teachers=False,
       shared_concat_teachers=False,
       c_gt_curriculum='A_B__',
       Y_tgt=None,
       W_teachers='generate',
       use_X=True,
       metric='cosine',
       teacher_mode='orthogonal',
       num_blocks=20,
       t_tot=20,
       T_tot=1000,
       block_duration=1.0,
       W1_tau=0.04,
       W2_tau=0.01,
       dt=0.01,
       log_every=1,
       T_tape=1000,
       dt_tape=0.01,
       control='deep_mono',
       data_out_dir='data_internal/FC_search/block_W2tau_search/',
       results_out_dir='results_internal/FC_search/block_W2tau_search/',
       num_shared_contexts=0,
       mixing_factor=0.5,
       W_regularization_strength=0.0,
       turn_off_regularization=False,
       log_aux=True,
        )
# Out:
# [WARNING] [2024-10-08 14:05:37,258] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!

# %%
block_hpams = [0.8, 0.6, 0.4, 0.2, 0.1]
W2_tau_hpams = [0.0075, 0.01, 0.0125, 0.015, 0.02]

# %%
mean_concat_cossim = np.zeros((len(block_hpams), len(W2_tau_hpams)))
last_concat_cossim = np.zeros((len(block_hpams), len(W2_tau_hpams)))

for i in range(len(block_hpams)):
    for j in range(len(W2_tau_hpams)):
        cfg = copy.deepcopy(shared_cfg)
        cfg.W2_tau = W2_tau_hpams[j]
        cfg.block_duration = block_hpams[i]
        cfg.name = f'block_{cfg.block_duration}_W2tau_{cfg.W2_tau}'
        data_path = Path(cfg.data_out_dir) 
        tape, cfg = get_data(cfg)
        mean_concat_cossim[i,j] = np.mean(tape.concat_cossim)  
        last_concat_cossim[i,j] = np.mean(tape.concat_cossim[:,-1])

np.save(data_path / 'mean_concat_cossim.npy', mean_concat_cossim)
np.save(data_path / 'last_concat_cossim.npy', last_concat_cossim)
with open(data_path / 'cfg.json', 'w') as f:
    json.dump(shared_cfg.__dict__, f)
# Out:
# [WARNING] [2024-10-08 14:05:37,677] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:05:37,679] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:05:37,846] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:05:37,847] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:05:37,924] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [INFO] [2024-10-08 14:05:37,955] in lcs.joint_learning: Running 10 seeds on device TFRT_CPU_0 with config Config(input_size=20,
#        output_size=10,
#        num_seeds=10,
#        num_contexts=2,
#        num_paths=2,
#        batch_size=200,
#        initialization_scale=0.01,
#        gate_second=True,
#        turn_off_regularization=False,
#        regularization_strength=0.25,
#        num_layers=2,
#        hidden_size=10,
#        context_model=False,
#        name='block_0.8_W2tau_0.0125',
#        regularization_type=[('nonnegative', 1), ('gating_manifold_L2', 10.0)],
#        shared_teachers=False,
#        shared_concat_teachers=False,
#        c_gt_curriculum='A_B__',
#        Y_tgt=None,
#        W_teachers='generate',
#        use_X=True,
#        metric='cosine',
#        teacher_mode='orthogonal',
#        teacher_xx=0.0,
#        t_tot=20,
#        T_tot=2000,
#        num_blocks=25,
#        block_duration=0.8,
#        W_lr=None,
#        W1_lr=None,
#        W2_lr=None,
#        c_lr=None,
#        W_tau=None,
#        W1_tau=0.04,
#        W2_tau=0.0125,
#        c_tau=0.4,
#        dt=0.01,
#        log_every=1,
#        T_tape=1000,
#        dt_tape=0.02,
#        control='deep_mono',
#        data_out_dir='data_internal/joint_learning/deep_mono_search/block_W2tau_search/',
#        results_out_dir='results_internal/joint_learning/deep_mono_search/block_W2tau_search/',
#        num_shared_contexts=0,
#        mixing_factor=0.5,
#        W_regularization_strength=0.0,
#        log_aux=True)
# [WARNING] [2024-10-08 14:05:53,039] in lcs.joint_learning: grad norm W2 x lr is too large at 0.5474309325218201, not operating in Gradient Flow regime. Consider reducing dt=0.0100.
# [WARNING] [2024-10-08 14:05:55,751] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:05:55,754] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:05:55,854] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:05:55,857] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:05:55,923] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:05:55,924] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:05:56,091] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:05:56,092] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:05:56,156] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [INFO] [2024-10-08 14:05:56,306] in lcs.joint_learning: Running 10 seeds on device TFRT_CPU_0 with config Config(input_size=20,
#        output_size=10,
#        num_seeds=10,
#        num_contexts=2,
#        num_paths=2,
#        batch_size=200,
#        initialization_scale=0.01,
#        gate_second=True,
#        turn_off_regularization=False,
#        regularization_strength=0.25,
#        num_layers=2,
#        hidden_size=10,
#        context_model=False,
#        name='block_0.6_W2tau_0.0125',
#        regularization_type=[('nonnegative', 1), ('gating_manifold_L2', 10.0)],
#        shared_teachers=False,
#        shared_concat_teachers=False,
#        c_gt_curriculum='A_B__',
#        Y_tgt=None,
#        W_teachers='generate',
#        use_X=True,
#        metric='cosine',
#        teacher_mode='orthogonal',
#        teacher_xx=0.0,
#        t_tot=20,
#        T_tot=2000,
#        num_blocks=34,
#        block_duration=0.6,
#        W_lr=None,
#        W1_lr=None,
#        W2_lr=None,
#        c_lr=None,
#        W_tau=None,
#        W1_tau=0.04,
#        W2_tau=0.0125,
#        c_tau=0.4,
#        dt=0.01,
#        log_every=1,
#        T_tape=1000,
#        dt_tape=0.02,
#        control='deep_mono',
#        data_out_dir='data_internal/joint_learning/deep_mono_search/block_W2tau_search/',
#        results_out_dir='results_internal/joint_learning/deep_mono_search/block_W2tau_search/',
#        num_shared_contexts=0,
#        mixing_factor=0.5,
#        W_regularization_strength=0.0,
#        log_aux=True)
# [WARNING] [2024-10-08 14:06:10,950] in lcs.joint_learning: grad norm W2 x lr is too large at 0.5474309325218201, not operating in Gradient Flow regime. Consider reducing dt=0.0100.
# [WARNING] [2024-10-08 14:06:12,853] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:06:12,857] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:06:12,956] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:06:12,958] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:06:13,025] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:06:13,025] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:06:13,076] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:06:13,077] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:06:13,127] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [INFO] [2024-10-08 14:06:13,146] in lcs.joint_learning: Running 10 seeds on device TFRT_CPU_0 with config Config(input_size=20,
#        output_size=10,
#        num_seeds=10,
#        num_contexts=2,
#        num_paths=2,
#        batch_size=200,
#        initialization_scale=0.01,
#        gate_second=True,
#        turn_off_regularization=False,
#        regularization_strength=0.25,
#        num_layers=2,
#        hidden_size=10,
#        context_model=False,
#        name='block_0.4_W2tau_0.0125',
#        regularization_type=[('nonnegative', 1), ('gating_manifold_L2', 10.0)],
#        shared_teachers=False,
#        shared_concat_teachers=False,
#        c_gt_curriculum='A_B__',
#        Y_tgt=None,
#        W_teachers='generate',
#        use_X=True,
#        metric='cosine',
#        teacher_mode='orthogonal',
#        teacher_xx=0.0,
#        t_tot=20,
#        T_tot=2000,
#        num_blocks=50,
#        block_duration=0.4,
#        W_lr=None,
#        W1_lr=None,
#        W2_lr=None,
#        c_lr=None,
#        W_tau=None,
#        W1_tau=0.04,
#        W2_tau=0.0125,
#        c_tau=0.4,
#        dt=0.01,
#        log_every=1,
#        T_tape=1000,
#        dt_tape=0.02,
#        control='deep_mono',
#        data_out_dir='data_internal/joint_learning/deep_mono_search/block_W2tau_search/',
#        results_out_dir='results_internal/joint_learning/deep_mono_search/block_W2tau_search/',
#        num_shared_contexts=0,
#        mixing_factor=0.5,
#        W_regularization_strength=0.0,
#        log_aux=True)
# [WARNING] [2024-10-08 14:06:33,496] in lcs.joint_learning: grad norm W2 x lr is too large at 0.5474309325218201, not operating in Gradient Flow regime. Consider reducing dt=0.0100.
# [WARNING] [2024-10-08 14:06:35,327] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:06:35,336] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:06:35,426] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:06:35,426] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:06:35,480] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:06:35,481] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:06:35,531] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:06:35,532] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:06:35,583] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [INFO] [2024-10-08 14:06:35,603] in lcs.joint_learning: Running 10 seeds on device TFRT_CPU_0 with config Config(input_size=20,
#        output_size=10,
#        num_seeds=10,
#        num_contexts=2,
#        num_paths=2,
#        batch_size=200,
#        initialization_scale=0.01,
#        gate_second=True,
#        turn_off_regularization=False,
#        regularization_strength=0.25,
#        num_layers=2,
#        hidden_size=10,
#        context_model=False,
#        name='block_0.2_W2tau_0.0125',
#        regularization_type=[('nonnegative', 1), ('gating_manifold_L2', 10.0)],
#        shared_teachers=False,
#        shared_concat_teachers=False,
#        c_gt_curriculum='A_B__',
#        Y_tgt=None,
#        W_teachers='generate',
#        use_X=True,
#        metric='cosine',
#        teacher_mode='orthogonal',
#        teacher_xx=0.0,
#        t_tot=20,
#        T_tot=2000,
#        num_blocks=100,
#        block_duration=0.2,
#        W_lr=None,
#        W1_lr=None,
#        W2_lr=None,
#        c_lr=None,
#        W_tau=None,
#        W1_tau=0.04,
#        W2_tau=0.0125,
#        c_tau=0.4,
#        dt=0.01,
#        log_every=1,
#        T_tape=1000,
#        dt_tape=0.02,
#        control='deep_mono',
#        data_out_dir='data_internal/joint_learning/deep_mono_search/block_W2tau_search/',
#        results_out_dir='results_internal/joint_learning/deep_mono_search/block_W2tau_search/',
#        num_shared_contexts=0,
#        mixing_factor=0.5,
#        W_regularization_strength=0.0,
#        log_aux=True)
# [WARNING] [2024-10-08 14:06:50,390] in lcs.joint_learning: grad norm W2 x lr is too large at 0.5474309325218201, not operating in Gradient Flow regime. Consider reducing dt=0.0100.
# [WARNING] [2024-10-08 14:06:52,403] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:06:52,412] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:06:52,513] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:06:52,519] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:06:52,586] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:06:52,587] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:06:52,670] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:06:52,672] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:06:52,755] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [INFO] [2024-10-08 14:06:52,776] in lcs.joint_learning: Running 10 seeds on device TFRT_CPU_0 with config Config(input_size=20,
#        output_size=10,
#        num_seeds=10,
#        num_contexts=2,
#        num_paths=2,
#        batch_size=200,
#        initialization_scale=0.01,
#        gate_second=True,
#        turn_off_regularization=False,
#        regularization_strength=0.25,
#        num_layers=2,
#        hidden_size=10,
#        context_model=False,
#        name='block_0.1_W2tau_0.0125',
#        regularization_type=[('nonnegative', 1), ('gating_manifold_L2', 10.0)],
#        shared_teachers=False,
#        shared_concat_teachers=False,
#        c_gt_curriculum='A_B__',
#        Y_tgt=None,
#        W_teachers='generate',
#        use_X=True,
#        metric='cosine',
#        teacher_mode='orthogonal',
#        teacher_xx=0.0,
#        t_tot=20,
#        T_tot=2000,
#        num_blocks=200,
#        block_duration=0.1,
#        W_lr=None,
#        W1_lr=None,
#        W2_lr=None,
#        c_lr=None,
#        W_tau=None,
#        W1_tau=0.04,
#        W2_tau=0.0125,
#        c_tau=0.4,
#        dt=0.01,
#        log_every=1,
#        T_tape=1000,
#        dt_tape=0.02,
#        control='deep_mono',
#        data_out_dir='data_internal/joint_learning/deep_mono_search/block_W2tau_search/',
#        results_out_dir='results_internal/joint_learning/deep_mono_search/block_W2tau_search/',
#        num_shared_contexts=0,
#        mixing_factor=0.5,
#        W_regularization_strength=0.0,
#        log_aux=True)
# [WARNING] [2024-10-08 14:07:08,257] in lcs.joint_learning: grad norm W2 x lr is too large at 0.5474309325218201, not operating in Gradient Flow regime. Consider reducing dt=0.0100.
# [WARNING] [2024-10-08 14:07:10,232] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:07:10,237] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:07:10,331] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:07:10,336] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!

# %%
shared_cfg = Config(input_size=20,
       output_size=10,
       num_seeds=10, #1,
       num_contexts=2,
       num_paths=2,
       batch_size=200,
       initialization_scale=0.01,
       regularization_strength=0.22, 
       num_layers=2,
       hidden_size=10,
       context_model=False,
       name='',
       regularization_type=[('nonnegative', 1),
                            ('gating_manifold_L2', 10.0)],
       shared_teachers=False,
       shared_concat_teachers=False,
       c_gt_curriculum='A_B__',
       Y_tgt=None,
       W_teachers='generate',
       use_X=True,
       metric='cosine',
       teacher_mode='orthogonal',
       num_blocks=20,
       t_tot=20,
       T_tot=1000,
       block_duration=1.0,
       W1_tau=0.04, 
       W2_tau=0.01,
       dt=0.01,
       log_every=1,
       T_tape=1000,
       dt_tape=0.01,
       control='deep_mono',
       data_out_dir='data_internal/FC_search/block_reg_search/',
       results_out_dir='results_internal/FC_search/block_reg_search/',
       num_shared_contexts=0,
       mixing_factor=0.5,
       W_regularization_strength=0.0,
       turn_off_regularization=False,
       log_aux=True,
        )
# Out:
# [WARNING] [2024-10-08 14:29:55,662] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!

# %%
block_hpams = [0.8, 0.6, 0.4, 0.2, 0.1]
reg_hpams = [0, 0.2, 0.25, 0.3, 0.35]

# %%
mean_concat_cossim = np.zeros((len(block_hpams), len(reg_hpams)))
last_concat_cossim = np.zeros((len(block_hpams), len(reg_hpams)))

for i in range(len(block_hpams)):
    for j in range(len(reg_hpams)):
        cfg = copy.deepcopy(shared_cfg)
        cfg.regularization_strength = reg_hpams[j]
        cfg.block_duration = block_hpams[i]
        cfg.name = f'block_{cfg.block_duration}_reg_{cfg.regularization_strength}'
        data_path = Path(cfg.data_out_dir) 
        tape, cfg = get_data(cfg)
        mean_concat_cossim[i,j] = np.mean(tape.concat_cossim) 
        last_concat_cossim[i,j] = np.mean(tape.concat_cossim[:,-1])

np.save(data_path / 'mean_concat_cossim.npy', mean_concat_cossim)
np.save(data_path / 'last_concat_cossim.npy', last_concat_cossim)
with open(data_path / 'cfg.json', 'w') as f:
    json.dump(shared_cfg.__dict__, f)
# Out:
# [WARNING] [2024-10-08 14:29:56,314] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:29:56,317] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:29:56,458] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:29:56,459] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:29:56,546] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:29:56,547] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:29:56,600] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:29:56,600] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:29:56,653] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:29:56,654] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:29:56,720] in run_script: Data found at data_internal/joint_learning/deep_mono_search/block_reg_search/block_0.8_reg_0.35 but with different config. Re-running simulation.
# [INFO] [2024-10-08 14:29:56,760] in lcs.joint_learning: Running 10 seeds on device TFRT_CPU_0 with config Config(input_size=20,
#        output_size=10,
#        num_seeds=10,
#        num_contexts=2,
#        num_paths=2,
#        batch_size=200,
#        initialization_scale=0.01,
#        gate_second=True,
#        turn_off_regularization=False,
#        regularization_strength=0.35,
#        num_layers=2,
#        hidden_size=10,
#        context_model=False,
#        name='block_0.8_reg_0.35',
#        regularization_type=[('nonnegative', 1), ('gating_manifold_L2', 10.0)],
#        shared_teachers=False,
#        shared_concat_teachers=False,
#        c_gt_curriculum='A_B__',
#        Y_tgt=None,
#        W_teachers='generate',
#        use_X=True,
#        metric='cosine',
#        teacher_mode='orthogonal',
#        teacher_xx=0.0,
#        t_tot=20,
#        T_tot=2000,
#        num_blocks=25,
#        block_duration=0.8,
#        W_lr=None,
#        W1_lr=None,
#        W2_lr=None,
#        c_lr=None,
#        W_tau=None,
#        W1_tau=0.04,
#        W2_tau=0.01,
#        c_tau=0.4,
#        dt=0.01,
#        log_every=1,
#        T_tape=1000,
#        dt_tape=0.02,
#        control='deep_mono',
#        data_out_dir='data_internal/joint_learning/deep_mono_search/block_reg_search/',
#        results_out_dir='results_internal/joint_learning/deep_mono_search/block_reg_search/',
#        num_shared_contexts=0,
#        mixing_factor=0.5,
#        W_regularization_strength=0.0,
#        log_aux=True)
# [WARNING] [2024-10-08 14:30:11,006] in lcs.joint_learning: grad norm W2 x lr is too large at 0.7664034962654114, not operating in Gradient Flow regime. Consider reducing dt=0.0100.
# [WARNING] [2024-10-08 14:30:12,662] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:30:12,671] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:30:12,748] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:30:12,749] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:30:12,814] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:30:12,814] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:30:12,874] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:30:12,875] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:30:12,928] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:30:12,929] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:30:12,980] in run_script: Data found at data_internal/joint_learning/deep_mono_search/block_reg_search/block_0.6_reg_0.35 but with different config. Re-running simulation.
# [INFO] [2024-10-08 14:30:13,018] in lcs.joint_learning: Running 10 seeds on device TFRT_CPU_0 with config Config(input_size=20,
#        output_size=10,
#        num_seeds=10,
#        num_contexts=2,
#        num_paths=2,
#        batch_size=200,
#        initialization_scale=0.01,
#        gate_second=True,
#        turn_off_regularization=False,
#        regularization_strength=0.35,
#        num_layers=2,
#        hidden_size=10,
#        context_model=False,
#        name='block_0.6_reg_0.35',
#        regularization_type=[('nonnegative', 1), ('gating_manifold_L2', 10.0)],
#        shared_teachers=False,
#        shared_concat_teachers=False,
#        c_gt_curriculum='A_B__',
#        Y_tgt=None,
#        W_teachers='generate',
#        use_X=True,
#        metric='cosine',
#        teacher_mode='orthogonal',
#        teacher_xx=0.0,
#        t_tot=20,
#        T_tot=2000,
#        num_blocks=34,
#        block_duration=0.6,
#        W_lr=None,
#        W1_lr=None,
#        W2_lr=None,
#        c_lr=None,
#        W_tau=None,
#        W1_tau=0.04,
#        W2_tau=0.01,
#        c_tau=0.4,
#        dt=0.01,
#        log_every=1,
#        T_tape=1000,
#        dt_tape=0.02,
#        control='deep_mono',
#        data_out_dir='data_internal/joint_learning/deep_mono_search/block_reg_search/',
#        results_out_dir='results_internal/joint_learning/deep_mono_search/block_reg_search/',
#        num_shared_contexts=0,
#        mixing_factor=0.5,
#        W_regularization_strength=0.0,
#        log_aux=True)
# [WARNING] [2024-10-08 14:30:26,855] in lcs.joint_learning: grad norm W2 x lr is too large at 0.7664034962654114, not operating in Gradient Flow regime. Consider reducing dt=0.0100.
# [WARNING] [2024-10-08 14:30:28,529] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:30:28,538] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:30:28,623] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:30:28,624] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:30:28,691] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:30:28,692] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:30:28,745] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:30:28,746] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:30:28,796] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:30:28,796] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:30:28,843] in run_script: Data found at data_internal/joint_learning/deep_mono_search/block_reg_search/block_0.4_reg_0.35 but with different config. Re-running simulation.
# [INFO] [2024-10-08 14:30:28,874] in lcs.joint_learning: Running 10 seeds on device TFRT_CPU_0 with config Config(input_size=20,
#        output_size=10,
#        num_seeds=10,
#        num_contexts=2,
#        num_paths=2,
#        batch_size=200,
#        initialization_scale=0.01,
#        gate_second=True,
#        turn_off_regularization=False,
#        regularization_strength=0.35,
#        num_layers=2,
#        hidden_size=10,
#        context_model=False,
#        name='block_0.4_reg_0.35',
#        regularization_type=[('nonnegative', 1), ('gating_manifold_L2', 10.0)],
#        shared_teachers=False,
#        shared_concat_teachers=False,
#        c_gt_curriculum='A_B__',
#        Y_tgt=None,
#        W_teachers='generate',
#        use_X=True,
#        metric='cosine',
#        teacher_mode='orthogonal',
#        teacher_xx=0.0,
#        t_tot=20,
#        T_tot=2000,
#        num_blocks=50,
#        block_duration=0.4,
#        W_lr=None,
#        W1_lr=None,
#        W2_lr=None,
#        c_lr=None,
#        W_tau=None,
#        W1_tau=0.04,
#        W2_tau=0.01,
#        c_tau=0.4,
#        dt=0.01,
#        log_every=1,
#        T_tape=1000,
#        dt_tape=0.02,
#        control='deep_mono',
#        data_out_dir='data_internal/joint_learning/deep_mono_search/block_reg_search/',
#        results_out_dir='results_internal/joint_learning/deep_mono_search/block_reg_search/',
#        num_shared_contexts=0,
#        mixing_factor=0.5,
#        W_regularization_strength=0.0,
#        log_aux=True)
# [WARNING] [2024-10-08 14:30:43,419] in lcs.joint_learning: grad norm W2 x lr is too large at 0.7664034962654114, not operating in Gradient Flow regime. Consider reducing dt=0.0100.
# [WARNING] [2024-10-08 14:30:45,031] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:30:45,038] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:30:45,146] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:30:45,155] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:30:45,218] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:30:45,218] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:30:45,271] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:30:45,272] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:30:45,328] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:30:45,329] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:30:45,381] in run_script: Data found at data_internal/joint_learning/deep_mono_search/block_reg_search/block_0.2_reg_0.35 but with different config. Re-running simulation.
# [INFO] [2024-10-08 14:30:45,415] in lcs.joint_learning: Running 10 seeds on device TFRT_CPU_0 with config Config(input_size=20,
#        output_size=10,
#        num_seeds=10,
#        num_contexts=2,
#        num_paths=2,
#        batch_size=200,
#        initialization_scale=0.01,
#        gate_second=True,
#        turn_off_regularization=False,
#        regularization_strength=0.35,
#        num_layers=2,
#        hidden_size=10,
#        context_model=False,
#        name='block_0.2_reg_0.35',
#        regularization_type=[('nonnegative', 1), ('gating_manifold_L2', 10.0)],
#        shared_teachers=False,
#        shared_concat_teachers=False,
#        c_gt_curriculum='A_B__',
#        Y_tgt=None,
#        W_teachers='generate',
#        use_X=True,
#        metric='cosine',
#        teacher_mode='orthogonal',
#        teacher_xx=0.0,
#        t_tot=20,
#        T_tot=2000,
#        num_blocks=100,
#        block_duration=0.2,
#        W_lr=None,
#        W1_lr=None,
#        W2_lr=None,
#        c_lr=None,
#        W_tau=None,
#        W1_tau=0.04,
#        W2_tau=0.01,
#        c_tau=0.4,
#        dt=0.01,
#        log_every=1,
#        T_tape=1000,
#        dt_tape=0.02,
#        control='deep_mono',
#        data_out_dir='data_internal/joint_learning/deep_mono_search/block_reg_search/',
#        results_out_dir='results_internal/joint_learning/deep_mono_search/block_reg_search/',
#        num_shared_contexts=0,
#        mixing_factor=0.5,
#        W_regularization_strength=0.0,
#        log_aux=True)
# [WARNING] [2024-10-08 14:31:12,977] in lcs.joint_learning: grad norm W2 x lr is too large at 0.7664034962654114, not operating in Gradient Flow regime. Consider reducing dt=0.0100.
# [WARNING] [2024-10-08 14:31:14,765] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:31:14,780] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:31:14,873] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:31:14,874] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:31:14,934] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:31:14,935] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:31:15,002] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:31:15,003] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:31:15,062] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:31:15,063] in lcs.configs: Using a dt > 1e-3 introduces finite-size effects!
# [WARNING] [2024-10-08 14:31:15,109] in run_script: Data found at data_internal/joint_learning/deep_mono_search/block_reg_search/block_0.1_reg_0.35 but with different config. Re-running simulation.
# [INFO] [2024-10-08 14:31:15,145] in lcs.joint_learning: Running 10 seeds on device TFRT_CPU_0 with config Config(input_size=20,
#        output_size=10,
#        num_seeds=10,
#        num_contexts=2,
#        num_paths=2,
#        batch_size=200,
#        initialization_scale=0.01,
#        gate_second=True,
#        turn_off_regularization=False,
#        regularization_strength=0.35,
#        num_layers=2,
#        hidden_size=10,
#        context_model=False,
#        name='block_0.1_reg_0.35',
#        regularization_type=[('nonnegative', 1), ('gating_manifold_L2', 10.0)],
#        shared_teachers=False,
#        shared_concat_teachers=False,
#        c_gt_curriculum='A_B__',
#        Y_tgt=None,
#        W_teachers='generate',
#        use_X=True,
#        metric='cosine',
#        teacher_mode='orthogonal',
#        teacher_xx=0.0,
#        t_tot=20,
#        T_tot=2000,
#        num_blocks=200,
#        block_duration=0.1,
#        W_lr=None,
#        W1_lr=None,
#        W2_lr=None,
#        c_lr=None,
#        W_tau=None,
#        W1_tau=0.04,
#        W2_tau=0.01,
#        c_tau=0.4,
#        dt=0.01,
#        log_every=1,
#        T_tape=1000,
#        dt_tape=0.02,
#        control='deep_mono',
#        data_out_dir='data_internal/joint_learning/deep_mono_search/block_reg_search/',
#        results_out_dir='results_internal/joint_learning/deep_mono_search/block_reg_search/',
#        num_shared_contexts=0,
#        mixing_factor=0.5,
#        W_regularization_strength=0.0,
#        log_aux=True)
# [WARNING] [2024-10-08 14:31:29,808] in lcs.joint_learning: grad norm W2 x lr is too large at 0.7664034962654114, not operating in Gradient Flow regime. Consider reducing dt=0.0100.

# %%
data_path = Path('data_internal/joint_learning/deep_mono_search/block_W2tau_search/')
block_W2tau_mean_concat_cossim = np.load(data_path / 'mean_concat_cossim.npy')
block_W2tau_last_concat_cossim = np.load(data_path / 'last_concat_cossim.npy')

data_path = Path('data_internal/joint_learning/deep_mono_search/block_reg_search/')
block_reg_mean_concat_cossim = np.load(data_path / 'mean_concat_cossim.npy')
block_reg_last_concat_cossim = np.load(data_path / 'last_concat_cossim.npy')

# %%
init_plot_settings()
s = 2
fig = plt.figure(figsize=(s*TEXTWIDTH*.65*.75, s*PAGEHEIGHT*0.14*.75), layout='constrained')

mosaic = """
abd
"""

axd = fig.subplot_mosaic(mosaic, width_ratios=[6,6,0.35])

for ax in axd.values():
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)

ax_blocklength_clr = axd['a']
ax_blocklength_reg = axd['b']

# %%
vmin = 0.7
vmax = 1

cmap = matplotlib.colormaps['Oranges']
normalizer = Normalize(vmin, vmax)
im = cm.ScalarMappable(cmap=cmap, norm=normalizer)

ax = ax_blocklength_clr
im1 = ax.imshow(np.fliplr(block_W2tau_last_concat_cossim), cmap=cmap, vmin=vmin, vmax=vmax)
ax.set_xlabel(r'layer 2 weights learning rate $\tau_{W_1}/\tau_{W_2}$')
ax.set_ylabel(r'block length $\tau_B/\tau_{W_{1}}$')
default_x_ticks = range(len(W2_tau_hpams))
default_y_ticks = range(len(block_hpams))
ax.set_yticks(default_y_ticks, [20, 15, 10, 5, 2.5])
ax.set_xticks(default_x_ticks, [2, 2.66, 3.2, 4, 5.33])

ax = ax_blocklength_reg
im2 = ax.imshow(block_reg_last_concat_cossim, cmap=cmap, vmin=vmin, vmax=vmax) 
ax.set_xlabel(r'regularization strength $\lambda$')
ax.set_ylabel(r'block length $\tau_B/\tau_{W_1}$')
default_x_ticks = range(len(reg_hpams))
default_y_ticks = range(len(block_hpams))
ax.set_yticks(default_y_ticks, [20, 15, 10, 5, 2.5])
ax.set_xticks(default_x_ticks, reg_hpams)

fig.colorbar(im, cax=axd['d'], cmap=cmap, label='total alignment ' + r'$\langle \boldsymbol{W}^{\star} \boldsymbol{W}^{T}\rangle$', ticks=[0.7, 1]) 
fig
